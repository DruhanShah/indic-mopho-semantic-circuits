# %%
import torch
import torch.nn.functional as F
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from transformers import GPT2Tokenizer, GPT2LMHeadModel

print("Loading GPT-2 model and tokenizer...")
model_name = 'gpt2'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name, attn_implementation="eager")
model.eval()
tokenizer.pad_token = tokenizer.eos_token
print("Setup complete.")
# Out:
# Loading GPT-2 model and tokenizer...
# Setup complete.

# %%
Attention Map

# %%
def visualize_all_layers_for_sentence(text):
    """Visualizes the attention patterns for all heads in every layer for a sentence."""
    inputs = tokenizer(text, return_tensors='pt')
    with torch.no_grad():
        outputs = model(**inputs, output_attentions=True)
    tokens = tokenizer.convert_ids_to_tokens(inputs['input_ids'][0])

    for layer_idx, attention in enumerate(outputs.attentions):
        attention = attention.squeeze(0).detach().numpy()
        fig, axes = plt.subplots(3, 4, figsize=(16, 12))
        fig.suptitle(f'All Attention Heads for Layer {layer_idx}\nSentence: "{text}"', fontsize=20)
        for head_idx in range(model.config.n_head):
            ax = axes[head_idx // 4, head_idx % 4]
            sns.heatmap(attention[head_idx], xticklabels=tokens, yticklabels=tokens, cmap='viridis', ax=ax, cbar=False)
            ax.set_title(f'Head {head_idx}')
            ax.tick_params(axis='x', rotation=90)
        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        plt.show()

if __name__ == "__main__":
    print("--- Running a full visual exploration on a sample sentence. ---")
    visualize_all_layers_for_sentence("The doctor treated the patient because he was sick")
# Out:
# --- Running a full visual exploration on a sample sentence. ---

# %% [markdown]
# Functions

# %%
def find_token_position(tokens, target_word):
    """Helper function to find token position, handling GPT-2's Ġ prefix."""
    try: return tokens.index('Ġ' + target_word)
    except ValueError:
        try: return tokens.index(target_word)
        except ValueError:
            for i, token in enumerate(tokens):
                if target_word.lower() in token.lower(): return i
            raise ValueError(f"Token '{target_word}' not found in {tokens}")

def analyze_semantic_role_attention(sentence, arg0, predicate, arg1):
    """Analyzes all 6 semantic role attention patterns for a single sentence."""
    inputs = tokenizer(sentence, return_tensors='pt')
    tokens = tokenizer.convert_ids_to_tokens(inputs['input_ids'][0])
    try:
        arg0_pos, pred_pos, arg1_pos = (find_token_position(tokens, arg) for arg in (arg0, predicate, arg1))
    except ValueError:
        return None

    with torch.no_grad():
        outputs = model(**inputs, output_attentions=True)

    results = {}
    for layer in range(model.config.n_layer):
        attention = outputs.attentions[layer].squeeze(0)
        layer_results = {}
        for head in range(model.config.n_head):
            p = {'pred_to_arg0': attention[head, pred_pos, arg0_pos].item(),
                 'pred_to_arg1': attention[head, pred_pos, arg1_pos].item(),
                 'arg0_to_pred': attention[head, arg0_pos, pred_pos].item(),
                 'arg1_to_pred': attention[head, arg1_pos, pred_pos].item(),
                 'arg0_to_arg1': attention[head, arg0_pos, arg1_pos].item(),
                 'arg1_to_arg0': attention[head, arg1_pos, arg0_pos].item()}
            layer_results[head] = p
        results[layer] = layer_results
    return results

# %%
# The  Circuit Analysis Framework 

class CircuitAnalyzer:
    """A class to systematically find, validate, and test a circuit of specialist heads."""

    def __init__(self, name, relationship_key):
        self.name = name
        self.relationship_key = relationship_key
        self.specialist_heads = []
        print(f"Initialized analyzer for '{self.name}' ({self.relationship_key}) circuit.")

    def find_specialists(self, test_cases, threshold=0.15):
        # ... (This function remains the same)
        head_scores = {}
        for case in test_cases:
            results = analyze_semantic_role_attention(case['sentence'], case['arg0'], case['predicate'], case['arg1'])
            if results is None: continue
            for layer in range(model.config.n_layer):
                for head in range(model.config.n_head):
                    score = results[layer][head][self.relationship_key]
                    key = (layer, head)
                    if key not in head_scores: head_scores[key] = []
                    head_scores[key].append(score)
        candidates = []
        for (layer, head), scores in head_scores.items():
            if np.mean(scores) > threshold and np.min(scores) > threshold * 0.3:
                candidates.append({'layer': layer, 'head': head, 'avg_score': np.mean(scores), 'min_score': np.min(scores)})
        candidates.sort(key=lambda x: x['avg_score'], reverse=True)
        self.specialist_heads = [(c['layer'], c['head']) for c in candidates]
        print(f"\n--- DISCOVERY: Found {len(self.specialist_heads)} candidates for '{self.name}' circuit ---")
        for i, head in enumerate(candidates[:5]):
            print(f"  {i+1}. L{head['layer']}H{head['head']} | Avg Score: {head['avg_score']:.4f} | Min Score: {head['min_score']:.4f}")
        return self

    def run_distance_test(self, distance_cases):
        if not self.specialist_heads:
            print(f"\n--- VALIDATION (DISTANCE): No heads to test. Skipping. ---")
            return self
        print(f"\n--- VALIDATION (DISTANCE): Testing top 5 specialists for '{self.name}' circuit ---")
        for case in distance_cases:
            results = analyze_semantic_role_attention(case['sentence'], case['arg0'], case['predicate'], case['arg1'])
            print(f"On sentence: '{case['sentence']}'")
            print(f"  {'Head':<8} {'Score':<10}")
            for layer, head in self.specialist_heads[:5]:
                score = results[layer][head][self.relationship_key]
                print(f"  L{layer}H{head:<5} {score:<10.4f}")
        return self

    def _perform_single_ablation(self, prompt, heads_to_ablate, verbose=True):
        """Helper function with full sentence generation AND top-5 token analysis."""
        inputs = tokenizer(prompt, return_tensors='pt').to(model.device)
        
        # 1. Baseline (no ablation)
        with torch.no_grad():
            baseline_output = model.generate(
                inputs['input_ids'], max_length=inputs['input_ids'].shape[1] + 10,
                pad_token_id=tokenizer.eos_token_id, do_sample=False
            )
            baseline_text = tokenizer.decode(baseline_output[0], skip_special_tokens=True)
            baseline_logits = model(**inputs).logits[0, -1, :]
            baseline_probs = F.softmax(baseline_logits, dim=-1)
            baseline_top5 = torch.topk(baseline_probs, 5)
    
        # 2. Ablated run
        hooks = []
        def create_hook(h):
            def hook_fn(module, input, output):
                output[0][:, :, h*(model.config.n_embd//model.config.n_head):(h+1)*(model.config.n_embd//model.config.n_head)] = 0
                return output
            return hook_fn
        
        try:
            for layer, head in heads_to_ablate:
                hooks.append(model.transformer.h[layer].attn.register_forward_hook(create_hook(head)))
            with torch.no_grad():
                ablated_output = model.generate(
                    inputs['input_ids'], max_length=inputs['input_ids'].shape[1] + 10,
                    pad_token_id=tokenizer.eos_token_id, do_sample=False
                )
                ablated_text = tokenizer.decode(ablated_output[0], skip_special_tokens=True)
                ablated_logits = model(**inputs).logits[0, -1, :]
                ablated_probs = F.softmax(ablated_logits, dim=-1)
                ablated_top5 = torch.topk(ablated_probs, 5)
        finally:
            for hook in hooks: hook.remove()
    
        # 3. Calculate metrics
        generation_changed = baseline_text != ablated_text
        kl_div = F.kl_div(ablated_probs.log(), baseline_probs, reduction='sum').item()
        
        # 4. Store top-5 predictions for both baseline and ablated
        baseline_predictions = [
            {'token': tokenizer.decode(baseline_top5.indices[i]), 
             'prob': baseline_top5.values[i].item()}
            for i in range(5)
        ]
        ablated_predictions = [
            {'token': tokenizer.decode(ablated_top5.indices[i]), 
             'prob': ablated_top5.values[i].item()}
            for i in range(5)
        ]
        
        # 5. Print detailed comparison (if verbose)
        if verbose:
            print(f"\nPrompt: '{prompt}'")
            print("-" * 50)
            
            print("BASELINE Top 5:")
            for i, pred in enumerate(baseline_predictions):
                print(f"  {i+1}. '{pred['token']}' (prob: {pred['prob']:.4f})")
            
            print("\nABLATED Top 5:")
            for i, pred in enumerate(ablated_predictions):
                print(f"  {i+1}. '{pred['token']}' (prob: {pred['prob']:.4f})")
            
            print("\n---")
            print(f"  Baseline Generated: {baseline_text}")
            print(f"  Ablated Generated:  {ablated_text}")
            
            print(f"\n  Generation Changed: {generation_changed}")
            print(f"  KL Divergence: {kl_div:.4f}")
    
        # 6. Return comprehensive metrics
        return {
            'prompt': prompt,
            'baseline_text': baseline_text,
            'ablated_text': ablated_text,
            'generation_changed': generation_changed,
            'kl_divergence': kl_div,
            'baseline_top5': baseline_predictions,
            'ablated_top5': ablated_predictions
        }


    def run_ablation_test(self, test_prompts):
        """UPGRADED: Runs a multi-stage causal test with detailed summary statistics."""
        if not self.specialist_heads:
            print(f"\n--- CAUSAL TEST (ABLATION): No heads to test. Skipping. ---")
            return self
        top_3_heads = self.specialist_heads[:3]
        if not top_3_heads:
             print(f"\n--- CAUSAL TEST (ABLATION): Fewer than 1 head found. Skipping. ---")
             return self
    
        print(f"\n--- CAUSAL TEST (ABLATION): Testing specialists for '{self.name}' circuit ---")
        
        # Storage for all results
        all_results = {
            'individual': [],
            'top3_combined': [],
            'all_combined': []
        }
        
        # --- Part 1: Individual Head Ablations (NOW TESTS ALL PROMPTS) ---
        print("\n" + "="*70)
        print("--- Part 1: Ablating Top 3 Heads Individually ---")
        print("="*70)
        
        for i, head in enumerate(top_3_heads):
            print(f"\n>>> Testing Head {i+1}/{len(top_3_heads)}: L{head[0]}H{head[1]}")
            print(f"    Testing across {len(test_prompts)} prompts...")
            
            head_results = []
            for prompt_idx, prompt in enumerate(test_prompts):
                # Only print verbose output for first 3 prompts to avoid clutter
                verbose = prompt_idx < 3
                if verbose:
                    print(f"\n  --- Prompt {prompt_idx+1}/{len(test_prompts)} ---")
                
                result = self._perform_single_ablation(prompt, [head], verbose=verbose)
                result['head'] = head
                result['prompt_idx'] = prompt_idx
                head_results.append(result)
            
            all_results['individual'].extend(head_results)
            
            # Print summary for this head across all prompts
            changed_count = sum(1 for r in head_results if r['generation_changed'])
            avg_kl = np.mean([r['kl_divergence'] for r in head_results])
            print(f"\n  Summary for L{head[0]}H{head[1]}:")
            print(f"    Prompts affected: {changed_count}/{len(test_prompts)}")
            print(f"    Average KL Divergence: {avg_kl:.4f}")
        
        # Print overall individual summary
        print("\n" + "-"*70)
        print("SUMMARY - Individual Head Ablations (All Heads, All Prompts):")
        print("-"*70)
        for head in top_3_heads:
            head_specific_results = [r for r in all_results['individual'] if r['head'] == head]
            changed = sum(1 for r in head_specific_results if r['generation_changed'])
            avg_kl = np.mean([r['kl_divergence'] for r in head_specific_results])
            print(f"  L{head[0]}H{head[1]}: {changed}/{len(test_prompts)} changed (Avg KL: {avg_kl:.4f})")
        
        # --- Part 2: Top 3 Combined ---
        print("\n" + "="*70)
        print(f"--- Part 2: Ablating Top 3 Heads Combined (Core Circuit) ---")
        print("="*70)
        print(f"\n>>> Testing All {len(top_3_heads)} Heads Together: {top_3_heads}")
        print(f"    Testing across {len(test_prompts)} prompts...")
        
        for prompt_idx, prompt in enumerate(test_prompts):
            # Only print verbose output for first 5 prompts
            verbose = prompt_idx < 5
            if verbose:
                print(f"\n  --- Prompt {prompt_idx+1}/{len(test_prompts)} ---")
            
            result = self._perform_single_ablation(prompt, top_3_heads, verbose=verbose)
            result['prompt_idx'] = prompt_idx
            all_results['top3_combined'].append(result)
        
        # Print top3 summary
        print("\n" + "-"*70)
        print("SUMMARY - Top 3 Combined Ablation:")
        print("-"*70)
        changed_top3 = sum(1 for r in all_results['top3_combined'] if r['generation_changed'])
        avg_kl_top3 = np.mean([r['kl_divergence'] for r in all_results['top3_combined']])
        print(f"Cases where generation changed: {changed_top3}/{len(test_prompts)}")
        print(f"Average KL Divergence: {avg_kl_top3:.4f}")
        
        # --- Part 3: All Heads Combined (if applicable) ---
        if len(self.specialist_heads) > len(top_3_heads):
            print("\n" + "="*70)
            print(f"--- Part 3: Ablating All {len(self.specialist_heads)} Found Heads Combined ---")
            print("="*70)
            print(f"    Testing across {len(test_prompts)} prompts...")
            
            for prompt_idx, prompt in enumerate(test_prompts):
                # Only print verbose output for first 5 prompts
                verbose = prompt_idx < 5
                if verbose:
                    print(f"\n  --- Prompt {prompt_idx+1}/{len(test_prompts)} ---")
                
                result = self._perform_single_ablation(prompt, self.specialist_heads, verbose=verbose)
                result['prompt_idx'] = prompt_idx
                all_results['all_combined'].append(result)
            
            # Print all heads summary
            print("\n" + "-"*70)
            print("SUMMARY - All Heads Combined Ablation:")
            print("-"*70)
            changed_all = sum(1 for r in all_results['all_combined'] if r['generation_changed'])
            avg_kl_all = np.mean([r['kl_divergence'] for r in all_results['all_combined']])
            print(f"Cases where generation changed: {changed_all}/{len(test_prompts)}")
            print(f"Average KL Divergence: {avg_kl_all:.4f}")
        
        # --- Final Overall Summary ---
        print("\n" + "="*70)
        print("FINAL SUMMARY - Circuit Causality Analysis")
        print("="*70)
        print(f"Circuit: {self.name}")
        print(f"Total specialist heads found: {len(self.specialist_heads)}")
        print(f"Number of test prompts: {len(test_prompts)}")
        print(f"\nIndividual heads (top 3):")
        for head in top_3_heads:
            head_results = [r for r in all_results['individual'] if r['head'] == head]
            changed = sum(1 for r in head_results if r['generation_changed'])
            print(f"  L{head[0]}H{head[1]}: {changed}/{len(test_prompts)} ({100*changed/len(test_prompts):.1f}%)")
        
        print(f"\nTop 3 combined: {changed_top3}/{len(test_prompts)} ({100*changed_top3/len(test_prompts):.1f}%)")
        if len(self.specialist_heads) > len(top_3_heads):
            print(f"All heads combined: {changed_all}/{len(test_prompts)} ({100*changed_all/len(test_prompts):.1f}%)")
        print("="*70 + "\n")
        
        # Store results for potential later analysis
        self.ablation_results = all_results
        
        return self

# %% [markdown]
# Test Data

# %%
main_test_cases = [
    {'sentence': 'The doctor treated the patient in the hospital', 'arg0': 'doctor', 'predicate': 'treated', 'arg1': 'patient'},
    {'sentence': 'The company launched the new product successfully', 'arg0': 'company', 'predicate': 'launched', 'arg1': 'product'},
    {'sentence': 'She read the book quietly in the library', 'arg0': 'She', 'predicate': 'read', 'arg1': 'book'},
    {'sentence': 'The teacher explained the lesson to the students', 'arg0': 'teacher', 'predicate': 'explained', 'arg1': 'lesson'},
    {'sentence': 'John gave Mary a beautiful gift yesterday', 'arg0': 'John', 'predicate': 'gave', 'arg1': 'gift'}
]
distance_test_cases = [
    {'sentence': 'The doctor treated the patient', 'arg0': 'doctor', 'predicate': 'treated', 'arg1': 'patient'},
    {'sentence': 'The doctor quickly treated the patient', 'arg0': 'doctor', 'predicate': 'treated', 'arg1': 'patient'},
    {'sentence': 'The doctor who arrived late treated the patient', 'arg0': 'doctor', 'predicate': 'treated', 'arg1': 'patient'}
]

ablation_prompts = [
    "The chef prepared the meal and she",
    "The company launched the product because it",
    "The teacher explained the lesson and he",
    "The scientist discovered the cure and she",
    "The artist painted the portrait while he",
    "The athlete won the championship because she",
    "The engineer designed the bridge and he",
    "The writer finished the novel so she",
    "The musician performed the concert and he",
    "The doctor diagnosed the illness before she",
    "The student solved the problem therefore he",
    "The manager approved the proposal and she",
    "The programmer debugged the code until he",
    "The researcher analyzed the data and she",
    "The pilot landed the plane safely and he",
]

# --- List of all circuits you want to systematically investigate ---
circuits_to_analyze = [
    CircuitAnalyzer(name="Subject->Verb", relationship_key='arg0_to_pred'),
    CircuitAnalyzer(name="Verb->Subject", relationship_key='pred_to_arg0'),
    CircuitAnalyzer(name="Verb->Object", relationship_key='pred_to_arg1'),
    CircuitAnalyzer(name="Object->Verb", relationship_key='arg1_to_pred'),
    CircuitAnalyzer(name="Subject->Object", relationship_key='arg0_to_arg1'),
    CircuitAnalyzer(name="Object->Subject", relationship_key='arg1_to_arg0'),
]

print("Test data and all 6 circuits are defined and ready for analysis.")
# Out:
# Initialized analyzer for 'Subject->Verb' (arg0_to_pred) circuit.
# Initialized analyzer for 'Verb->Subject' (pred_to_arg0) circuit.
# Initialized analyzer for 'Verb->Object' (pred_to_arg1) circuit.
# Initialized analyzer for 'Object->Verb' (arg1_to_pred) circuit.
# Initialized analyzer for 'Subject->Object' (arg0_to_arg1) circuit.
# Initialized analyzer for 'Object->Subject' (arg1_to_arg0) circuit.
# Test data and all 6 circuits are defined and ready for analysis.

# %%
# Subject->Verb
if __name__ == "__main__" and circuits_to_analyze:
    circuits_to_analyze[0].find_specialists(main_test_cases, threshold=0.1).run_distance_test(distance_test_cases).run_ablation_test(ablation_prompts)
# Out:
# --- DISCOVERY: Found 0 candidates for 'Subject->Verb' circuit ---
#
# --- VALIDATION (DISTANCE): No heads to test. Skipping. ---
#
# --- CAUSAL TEST (ABLATION): No heads to test. Skipping. ---

# %%
# Verb->Subject
if __name__ == "__main__" and len(circuits_to_analyze) > 1:
    circuits_to_analyze[1].find_specialists(main_test_cases, threshold=0.1).run_distance_test(distance_test_cases).run_ablation_test(ablation_prompts)
# Out:
# --- DISCOVERY: Found 86 candidates for 'Verb->Subject' circuit ---
#   1. L4H11 | Avg Score: 0.9995 | Min Score: 0.9981
#   2. L4H3 | Avg Score: 0.8984 | Min Score: 0.8717
#   3. L2H9 | Avg Score: 0.8847 | Min Score: 0.7362
#   4. L3H6 | Avg Score: 0.8287 | Min Score: 0.6442
#   5. L6H0 | Avg Score: 0.6355 | Min Score: 0.3703
#
# --- VALIDATION (DISTANCE): Testing top 5 specialists for 'Verb->Subject' circuit ---
# On sentence: 'The doctor treated the patient'
#   Head     Score
#   L4H11    0.9995
#   L4H3     0.8717
#   L2H9     0.7362
#   L3H6     0.8516
#   L6H0     0.3703
# On sentence: 'The doctor quickly treated the patient'
#   Head     Score
#   L4H11    0.0000
#   L4H3     0.7907
#   L2H9     0.5866
#   L3H6     0.7145
#   L6H0     0.3543
# On sentence: 'The doctor who arrived late treated the patient'
#   Head     Score
#   L4H11    0.0000
#   L4H3     0.5840
#   L2H9     0.2384
#   L3H6     0.1645
#   L6H0     0.3691
#
# --- CAUSAL TEST (ABLATION): Testing specialists for 'Verb->Subject' circuit ---
#
# ======================================================================
# --- Part 1: Ablating Top 3 Heads Individually ---
# ======================================================================
#
# >>> Testing Head 1/3: L4H11
#     Testing across 15 prompts...
#
#   --- Prompt 1/15 ---
#
# Prompt: 'The chef prepared the meal and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1207)
#   2. ' said' (prob: 0.0399)
#   3. ' took' (prob: 0.0366)
#   4. ' had' (prob: 0.0348)
#   5. ' asked' (prob: 0.0277)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1214)
#   2. ' said' (prob: 0.0408)
#   3. ' took' (prob: 0.0364)
#   4. ' had' (prob: 0.0347)
#   5. ' asked' (prob: 0.0272)
#
# ---
#   Baseline Generated: The chef prepared the meal and she was so excited to see the results.
#
#
#   Ablated Generated:  The chef prepared the meal and she was so excited to see it.
#
# "
#
#   Generation Changed: True
#   KL Divergence: 0.0003
#
#   --- Prompt 2/15 ---
#
# Prompt: 'The company launched the product because it'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1924)
#   2. ' wanted' (prob: 0.0989)
#   3. ' had' (prob: 0.0630)
#   4. ''s' (prob: 0.0527)
#   5. ' is' (prob: 0.0509)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1918)
#   2. ' wanted' (prob: 0.0974)
#   3. ' had' (prob: 0.0615)
#   4. ''s' (prob: 0.0579)
#   5. ' is' (prob: 0.0530)
#
# ---
#   Baseline Generated: The company launched the product because it was a way to make money on the internet.
#   Ablated Generated:  The company launched the product because it was "the most popular way to get a new
#
#   Generation Changed: True
#   KL Divergence: 0.0009
#
#   --- Prompt 3/15 ---
#
# Prompt: 'The teacher explained the lesson and he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.0975)
#   2. ' said' (prob: 0.0381)
#   3. ' then' (prob: 0.0300)
#   4. ' told' (prob: 0.0281)
#   5. ' asked' (prob: 0.0269)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.0991)
#   2. ' said' (prob: 0.0400)
#   3. ' then' (prob: 0.0306)
#   4. ' told' (prob: 0.0281)
#   5. ' took' (prob: 0.0264)
#
# ---
#   Baseline Generated: The teacher explained the lesson and he was taken aback by the teacher's response.
#
#   Ablated Generated:  The teacher explained the lesson and he was taken aback.
#
# "I'm not
#
#   Generation Changed: True
#   KL Divergence: 0.0005
#
#   Summary for L4H11:
#     Prompts affected: 5/15
#     Average KL Divergence: 0.0012
#
# >>> Testing Head 2/3: L4H3
#     Testing across 15 prompts...
#
#   --- Prompt 1/15 ---
#
# Prompt: 'The chef prepared the meal and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1207)
#   2. ' said' (prob: 0.0399)
#   3. ' took' (prob: 0.0366)
#   4. ' had' (prob: 0.0348)
#   5. ' asked' (prob: 0.0277)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1212)
#   2. ' said' (prob: 0.0408)
#   3. ' took' (prob: 0.0366)
#   4. ' had' (prob: 0.0358)
#   5. ' asked' (prob: 0.0276)
#
# ---
#   Baseline Generated: The chef prepared the meal and she was so excited to see the results.
#
#
#   Ablated Generated:  The chef prepared the meal and she was so excited to see the results.
#
#
#
#   Generation Changed: False
#   KL Divergence: 0.0003
#
#   --- Prompt 2/15 ---
#
# Prompt: 'The company launched the product because it'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1924)
#   2. ' wanted' (prob: 0.0989)
#   3. ' had' (prob: 0.0630)
#   4. ''s' (prob: 0.0527)
#   5. ' is' (prob: 0.0509)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1839)
#   2. ' wanted' (prob: 0.1106)
#   3. ' had' (prob: 0.0629)
#   4. ''s' (prob: 0.0502)
#   5. ' is' (prob: 0.0493)
#
# ---
#   Baseline Generated: The company launched the product because it was a way to make money on the internet.
#   Ablated Generated:  The company launched the product because it was a way to make money.
#
# "
#
#   Generation Changed: True
#   KL Divergence: 0.0025
#
#   --- Prompt 3/15 ---
#
# Prompt: 'The teacher explained the lesson and he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.0975)
#   2. ' said' (prob: 0.0381)
#   3. ' then' (prob: 0.0300)
#   4. ' told' (prob: 0.0281)
#   5. ' asked' (prob: 0.0269)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.0966)
#   2. ' said' (prob: 0.0376)
#   3. ' then' (prob: 0.0315)
#   4. ' told' (prob: 0.0275)
#   5. ' took' (prob: 0.0272)
#
# ---
#   Baseline Generated: The teacher explained the lesson and he was taken aback by the teacher's response.
#
#   Ablated Generated:  The teacher explained the lesson and he was taken to the hospital.
#
# "I
#
#   Generation Changed: True
#   KL Divergence: 0.0004
#
#   Summary for L4H3:
#     Prompts affected: 6/15
#     Average KL Divergence: 0.0012
#
# >>> Testing Head 3/3: L2H9
#     Testing across 15 prompts...
#
#   --- Prompt 1/15 ---
#
# Prompt: 'The chef prepared the meal and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1207)
#   2. ' said' (prob: 0.0399)
#   3. ' took' (prob: 0.0366)
#   4. ' had' (prob: 0.0348)
#   5. ' asked' (prob: 0.0277)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1204)
#   2. ' said' (prob: 0.0393)
#   3. ' took' (prob: 0.0367)
#   4. ' had' (prob: 0.0352)
#   5. ' asked' (prob: 0.0271)
#
# ---
#   Baseline Generated: The chef prepared the meal and she was so excited to see the results.
#
#
#   Ablated Generated:  The chef prepared the meal and she was so excited to see the chef's face.
#
#   Generation Changed: True
#   KL Divergence: 0.0004
#
#   --- Prompt 2/15 ---
#
# Prompt: 'The company launched the product because it'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1924)
#   2. ' wanted' (prob: 0.0989)
#   3. ' had' (prob: 0.0630)
#   4. ''s' (prob: 0.0527)
#   5. ' is' (prob: 0.0509)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1907)
#   2. ' wanted' (prob: 0.1018)
#   3. ' had' (prob: 0.0634)
#   4. ' is' (prob: 0.0516)
#   5. ''s' (prob: 0.0512)
#
# ---
#   Baseline Generated: The company launched the product because it was a way to make money on the internet.
#   Ablated Generated:  The company launched the product because it was a way to make money on the internet.
#
#   Generation Changed: False
#   KL Divergence: 0.0003
#
#   --- Prompt 3/15 ---
#
# Prompt: 'The teacher explained the lesson and he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.0975)
#   2. ' said' (prob: 0.0381)
#   3. ' then' (prob: 0.0300)
#   4. ' told' (prob: 0.0281)
#   5. ' asked' (prob: 0.0269)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.0960)
#   2. ' said' (prob: 0.0377)
#   3. ' then' (prob: 0.0328)
#   4. ' told' (prob: 0.0271)
#   5. ' asked' (prob: 0.0268)
#
# ---
#   Baseline Generated: The teacher explained the lesson and he was taken aback by the teacher's response.
#
#   Ablated Generated:  The teacher explained the lesson and he was taken aback by the teacher's response.
#
#
#   Generation Changed: False
#   KL Divergence: 0.0005
#
#   Summary for L2H9:
#     Prompts affected: 1/15
#     Average KL Divergence: 0.0009
#
# ----------------------------------------------------------------------
# SUMMARY - Individual Head Ablations (All Heads, All Prompts):
# ----------------------------------------------------------------------
#   L4H11: 5/15 changed (Avg KL: 0.0012)
#   L4H3: 6/15 changed (Avg KL: 0.0012)
#   L2H9: 1/15 changed (Avg KL: 0.0009)
#
# ======================================================================
# --- Part 2: Ablating Top 3 Heads Combined (Core Circuit) ---
# ======================================================================
#
# >>> Testing All 3 Heads Together: [(4, 11), (4, 3), (2, 9)]
#     Testing across 15 prompts...
#
#   --- Prompt 1/15 ---
#
# Prompt: 'The chef prepared the meal and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1207)
#   2. ' said' (prob: 0.0399)
#   3. ' took' (prob: 0.0366)
#   4. ' had' (prob: 0.0348)
#   5. ' asked' (prob: 0.0277)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1215)
#   2. ' said' (prob: 0.0410)
#   3. ' took' (prob: 0.0364)
#   4. ' had' (prob: 0.0361)
#   5. ' asked' (prob: 0.0263)
#
# ---
#   Baseline Generated: The chef prepared the meal and she was so excited to see the results.
#
#
#   Ablated Generated:  The chef prepared the meal and she was so excited to see it.
#
# "
#
#   Generation Changed: True
#   KL Divergence: 0.0011
#
#   --- Prompt 2/15 ---
#
# Prompt: 'The company launched the product because it'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1924)
#   2. ' wanted' (prob: 0.0989)
#   3. ' had' (prob: 0.0630)
#   4. ''s' (prob: 0.0527)
#   5. ' is' (prob: 0.0509)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1812)
#   2. ' wanted' (prob: 0.1116)
#   3. ' had' (prob: 0.0616)
#   4. ''s' (prob: 0.0541)
#   5. ' is' (prob: 0.0526)
#
# ---
#   Baseline Generated: The company launched the product because it was a way to make money on the internet.
#   Ablated Generated:  The company launched the product because it was "the most popular way to get a new
#
#   Generation Changed: True
#   KL Divergence: 0.0032
#
#   --- Prompt 3/15 ---
#
# Prompt: 'The teacher explained the lesson and he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.0975)
#   2. ' said' (prob: 0.0381)
#   3. ' then' (prob: 0.0300)
#   4. ' told' (prob: 0.0281)
#   5. ' asked' (prob: 0.0269)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.0969)
#   2. ' said' (prob: 0.0391)
#   3. ' then' (prob: 0.0351)
#   4. ' took' (prob: 0.0268)
#   5. ' told' (prob: 0.0264)
#
# ---
#   Baseline Generated: The teacher explained the lesson and he was taken aback by the teacher's response.
#
#   Ablated Generated:  The teacher explained the lesson and he was taken to the hospital.
#
# "I
#
#   Generation Changed: True
#   KL Divergence: 0.0012
#
#   --- Prompt 4/15 ---
#
# Prompt: 'The scientist discovered the cure and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1324)
#   2. ' became' (prob: 0.0302)
#   3. ' took' (prob: 0.0238)
#   4. ' had' (prob: 0.0233)
#   5. ' began' (prob: 0.0230)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1344)
#   2. ' became' (prob: 0.0302)
#   3. ' took' (prob: 0.0239)
#   4. ' had' (prob: 0.0236)
#   5. ''s' (prob: 0.0219)
#
# ---
#   Baseline Generated: The scientist discovered the cure and she was able to cure herself.
#
# The scientist
#   Ablated Generated:  The scientist discovered the cure and she was able to cure herself.
#
# The scientist
#
#   Generation Changed: False
#   KL Divergence: 0.0011
#
#   --- Prompt 5/15 ---
#
# Prompt: 'The artist painted the portrait while he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.6342)
#   2. ' worked' (prob: 0.0320)
#   3. ' and' (prob: 0.0260)
#   4. ' sat' (prob: 0.0179)
#   5. ' had' (prob: 0.0125)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.6737)
#   2. ' worked' (prob: 0.0285)
#   3. ' and' (prob: 0.0255)
#   4. ' sat' (prob: 0.0161)
#   5. ' had' (prob: 0.0114)
#
# ---
#   Baseline Generated: The artist painted the portrait while he was in the hospital.
#
# The artist painted
#   Ablated Generated:  The artist painted the portrait while he was in the hospital.
#
# The artist was
#
#   Generation Changed: True
#   KL Divergence: 0.0043
#
# ----------------------------------------------------------------------
# SUMMARY - Top 3 Combined Ablation:
# ----------------------------------------------------------------------
# Cases where generation changed: 7/15
# Average KL Divergence: 0.0026
#
# ======================================================================
# --- Part 3: Ablating All 86 Found Heads Combined ---
# ======================================================================
#     Testing across 15 prompts...
#
#   --- Prompt 1/15 ---
#
# Prompt: 'The chef prepared the meal and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1207)
#   2. ' said' (prob: 0.0399)
#   3. ' took' (prob: 0.0366)
#   4. ' had' (prob: 0.0348)
#   5. ' asked' (prob: 0.0277)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.0735)
#   2. ' had' (prob: 0.0286)
#   3. ' took' (prob: 0.0229)
#   4. ' made' (prob: 0.0218)
#   5. ' and' (prob: 0.0215)
#
# ---
#   Baseline Generated: The chef prepared the meal and she was so excited to see the results.
#
#
#   Ablated Generated:  The chef prepared the meal and she was the first to make a point of view.
#
#   Generation Changed: True
#   KL Divergence: 0.2610
#
#   --- Prompt 2/15 ---
#
# Prompt: 'The company launched the product because it'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1924)
#   2. ' wanted' (prob: 0.0989)
#   3. ' had' (prob: 0.0630)
#   4. ''s' (prob: 0.0527)
#   5. ' is' (prob: 0.0509)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.2496)
#   2. ' is' (prob: 0.1334)
#   3. ''s' (prob: 0.1039)
#   4. ' had' (prob: 0.0498)
#   5. ' has' (prob: 0.0418)
#
# ---
#   Baseline Generated: The company launched the product because it was a way to make money on the internet.
#   Ablated Generated:  The company launched the product because it was a great idea.
#
#
# The company
#
#   Generation Changed: True
#   KL Divergence: 0.9962
#
#   --- Prompt 3/15 ---
#
# Prompt: 'The teacher explained the lesson and he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.0975)
#   2. ' said' (prob: 0.0381)
#   3. ' then' (prob: 0.0300)
#   4. ' told' (prob: 0.0281)
#   5. ' asked' (prob: 0.0269)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.0579)
#   2. '/' (prob: 0.0381)
#   3. ' said' (prob: 0.0345)
#   4. ' or' (prob: 0.0337)
#   5. ' did' (prob: 0.0300)
#
# ---
#   Baseline Generated: The teacher explained the lesson and he was taken aback by the teacher's response.
#
#   Ablated Generated:  The teacher explained the lesson and he was a good one.
#
#
# "I
#
#   Generation Changed: True
#   KL Divergence: 0.6076
#
#   --- Prompt 4/15 ---
#
# Prompt: 'The scientist discovered the cure and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1324)
#   2. ' became' (prob: 0.0302)
#   3. ' took' (prob: 0.0238)
#   4. ' had' (prob: 0.0233)
#   5. ' began' (prob: 0.0230)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1036)
#   2. 'pher' (prob: 0.0625)
#   3. ' is' (prob: 0.0456)
#   4. ' has' (prob: 0.0265)
#   5. ' had' (prob: 0.0231)
#
# ---
#   Baseline Generated: The scientist discovered the cure and she was able to cure herself.
#
# The scientist
#   Ablated Generated:  The scientist discovered the cure and she was a bit of a lot of money.
#
#
#   Generation Changed: True
#   KL Divergence: 0.4449
#
#   --- Prompt 5/15 ---
#
# Prompt: 'The artist painted the portrait while he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.6342)
#   2. ' worked' (prob: 0.0320)
#   3. ' and' (prob: 0.0260)
#   4. ' sat' (prob: 0.0179)
#   5. ' had' (prob: 0.0125)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.2479)
#   2. ' is' (prob: 0.0249)
#   3. ' painted' (prob: 0.0242)
#   4. ' had' (prob: 0.0222)
#   5. ' and' (prob: 0.0220)
#
# ---
#   Baseline Generated: The artist painted the portrait while he was in the hospital.
#
# The artist painted
#   Ablated Generated:  The artist painted the portrait while he was in the studio.
#
#
# The artist
#
#   Generation Changed: True
#   KL Divergence: 0.5376
#
# ----------------------------------------------------------------------
# SUMMARY - All Heads Combined Ablation:
# ----------------------------------------------------------------------
# Cases where generation changed: 15/15
# Average KL Divergence: 0.5677
#
# ======================================================================
# FINAL SUMMARY - Circuit Causality Analysis
# ======================================================================
# Circuit: Verb->Subject
# Total specialist heads found: 86
# Number of test prompts: 15
#
# Individual heads (top 3):
#   L4H11: 5/15 (33.3%)
#   L4H3: 6/15 (40.0%)
#   L2H9: 1/15 (6.7%)
#
# Top 3 combined: 7/15 (46.7%)
# All heads combined: 15/15 (100.0%)
# ======================================================================

# %%
# Verb->Object 
if __name__ == "__main__" and len(circuits_to_analyze) > 2:
    circuits_to_analyze[2].find_specialists(main_test_cases, threshold=0.1).run_distance_test(distance_test_cases).run_ablation_test(ablation_prompts)
# Out:
# --- DISCOVERY: Found 0 candidates for 'Verb->Object' circuit ---
#
# --- VALIDATION (DISTANCE): No heads to test. Skipping. ---
#
# --- CAUSAL TEST (ABLATION): No heads to test. Skipping. ---

# %%
# Object->Verb 
if __name__ == "__main__" and len(circuits_to_analyze) > 3:
    circuits_to_analyze[3].find_specialists(main_test_cases, threshold=0.1).run_distance_test(distance_test_cases).run_ablation_test(ablation_prompts)
# Out:
# --- DISCOVERY: Found 39 candidates for 'Object->Verb' circuit ---
#   1. L4H0 | Avg Score: 0.6170 | Min Score: 0.0870
#   2. L2H8 | Avg Score: 0.5641 | Min Score: 0.3255
#   3. L3H9 | Avg Score: 0.4666 | Min Score: 0.2716
#   4. L9H10 | Avg Score: 0.4406 | Min Score: 0.0840
#   5. L11H8 | Avg Score: 0.3290 | Min Score: 0.1522
#
# --- VALIDATION (DISTANCE): Testing top 5 specialists for 'Object->Verb' circuit ---
# On sentence: 'The doctor treated the patient'
#   Head     Score
#   L4H0     0.8740
#   L2H8     0.6012
#   L3H9     0.4257
#   L9H10    0.6758
#   L11H8     0.2324
# On sentence: 'The doctor quickly treated the patient'
#   Head     Score
#   L4H0     0.8644
#   L2H8     0.4867
#   L3H9     0.3605
#   L9H10    0.7746
#   L11H8     0.1363
# On sentence: 'The doctor who arrived late treated the patient'
#   Head     Score
#   L4H0     0.8057
#   L2H8     0.4672
#   L3H9     0.3279
#   L9H10    0.7926
#   L11H8     0.0923
#
# --- CAUSAL TEST (ABLATION): Testing specialists for 'Object->Verb' circuit ---
#
# ======================================================================
# --- Part 1: Ablating Top 3 Heads Individually ---
# ======================================================================
#
# >>> Testing Head 1/3: L4H0
#     Testing across 15 prompts...
#
#   --- Prompt 1/15 ---
#
# Prompt: 'The chef prepared the meal and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1207)
#   2. ' said' (prob: 0.0399)
#   3. ' took' (prob: 0.0366)
#   4. ' had' (prob: 0.0348)
#   5. ' asked' (prob: 0.0277)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1174)
#   2. ' said' (prob: 0.0397)
#   3. ' took' (prob: 0.0380)
#   4. ' had' (prob: 0.0343)
#   5. ' asked' (prob: 0.0281)
#
# ---
#   Baseline Generated: The chef prepared the meal and she was so excited to see the results.
#
#
#   Ablated Generated:  The chef prepared the meal and she was so excited to try it.
#
# "
#
#   Generation Changed: True
#   KL Divergence: 0.0006
#
#   --- Prompt 2/15 ---
#
# Prompt: 'The company launched the product because it'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1924)
#   2. ' wanted' (prob: 0.0989)
#   3. ' had' (prob: 0.0630)
#   4. ''s' (prob: 0.0527)
#   5. ' is' (prob: 0.0509)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1873)
#   2. ' wanted' (prob: 0.1092)
#   3. ' had' (prob: 0.0627)
#   4. ''s' (prob: 0.0489)
#   5. ' is' (prob: 0.0482)
#
# ---
#   Baseline Generated: The company launched the product because it was a way to make money on the internet.
#   Ablated Generated:  The company launched the product because it was "the most popular way to get a better
#
#   Generation Changed: True
#   KL Divergence: 0.0020
#
#   --- Prompt 3/15 ---
#
# Prompt: 'The teacher explained the lesson and he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.0975)
#   2. ' said' (prob: 0.0381)
#   3. ' then' (prob: 0.0300)
#   4. ' told' (prob: 0.0281)
#   5. ' asked' (prob: 0.0269)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.0985)
#   2. ' said' (prob: 0.0377)
#   3. ' then' (prob: 0.0294)
#   4. ' told' (prob: 0.0285)
#   5. ' asked' (prob: 0.0279)
#
# ---
#   Baseline Generated: The teacher explained the lesson and he was taken aback by the teacher's response.
#
#   Ablated Generated:  The teacher explained the lesson and he was taken to the hospital.
#
# "I
#
#   Generation Changed: True
#   KL Divergence: 0.0006
#
#   Summary for L4H0:
#     Prompts affected: 5/15
#     Average KL Divergence: 0.0012
#
# >>> Testing Head 2/3: L2H8
#     Testing across 15 prompts...
#
#   --- Prompt 1/15 ---
#
# Prompt: 'The chef prepared the meal and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1207)
#   2. ' said' (prob: 0.0399)
#   3. ' took' (prob: 0.0366)
#   4. ' had' (prob: 0.0348)
#   5. ' asked' (prob: 0.0277)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1196)
#   2. ' said' (prob: 0.0395)
#   3. ' took' (prob: 0.0363)
#   4. ' had' (prob: 0.0351)
#   5. ' asked' (prob: 0.0284)
#
# ---
#   Baseline Generated: The chef prepared the meal and she was so excited to see the results.
#
#
#   Ablated Generated:  The chef prepared the meal and she was so excited to see the chef's face.
#
#   Generation Changed: True
#   KL Divergence: 0.0003
#
#   --- Prompt 2/15 ---
#
# Prompt: 'The company launched the product because it'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1924)
#   2. ' wanted' (prob: 0.0989)
#   3. ' had' (prob: 0.0630)
#   4. ''s' (prob: 0.0527)
#   5. ' is' (prob: 0.0509)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1997)
#   2. ' wanted' (prob: 0.0948)
#   3. ' had' (prob: 0.0648)
#   4. ''s' (prob: 0.0524)
#   5. ' is' (prob: 0.0519)
#
# ---
#   Baseline Generated: The company launched the product because it was a way to make money on the internet.
#   Ablated Generated:  The company launched the product because it was a way to make money on the internet.
#
#   Generation Changed: False
#   KL Divergence: 0.0006
#
#   --- Prompt 3/15 ---
#
# Prompt: 'The teacher explained the lesson and he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.0975)
#   2. ' said' (prob: 0.0381)
#   3. ' then' (prob: 0.0300)
#   4. ' told' (prob: 0.0281)
#   5. ' asked' (prob: 0.0269)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.0946)
#   2. ' said' (prob: 0.0372)
#   3. ' then' (prob: 0.0302)
#   4. ' told' (prob: 0.0282)
#   5. ' asked' (prob: 0.0281)
#
# ---
#   Baseline Generated: The teacher explained the lesson and he was taken aback by the teacher's response.
#
#   Ablated Generated:  The teacher explained the lesson and he was taken aback by the teacher's response.
#
#
#   Generation Changed: False
#   KL Divergence: 0.0003
#
#   Summary for L2H8:
#     Prompts affected: 2/15
#     Average KL Divergence: 0.0006
#
# >>> Testing Head 3/3: L3H9
#     Testing across 15 prompts...
#
#   --- Prompt 1/15 ---
#
# Prompt: 'The chef prepared the meal and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1207)
#   2. ' said' (prob: 0.0399)
#   3. ' took' (prob: 0.0366)
#   4. ' had' (prob: 0.0348)
#   5. ' asked' (prob: 0.0277)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1234)
#   2. ' said' (prob: 0.0387)
#   3. ' took' (prob: 0.0363)
#   4. ' had' (prob: 0.0358)
#   5. ' asked' (prob: 0.0256)
#
# ---
#   Baseline Generated: The chef prepared the meal and she was so excited to see the results.
#
#
#   Ablated Generated:  The chef prepared the meal and she was so excited to see the results.
#
#
#
#   Generation Changed: False
#   KL Divergence: 0.0005
#
#   --- Prompt 2/15 ---
#
# Prompt: 'The company launched the product because it'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1924)
#   2. ' wanted' (prob: 0.0989)
#   3. ' had' (prob: 0.0630)
#   4. ''s' (prob: 0.0527)
#   5. ' is' (prob: 0.0509)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1982)
#   2. ' wanted' (prob: 0.0899)
#   3. ' had' (prob: 0.0638)
#   4. ''s' (prob: 0.0540)
#   5. ' is' (prob: 0.0511)
#
# ---
#   Baseline Generated: The company launched the product because it was a way to make money on the internet.
#   Ablated Generated:  The company launched the product because it was a way to make money from the sale of
#
#   Generation Changed: True
#   KL Divergence: 0.0018
#
#   --- Prompt 3/15 ---
#
# Prompt: 'The teacher explained the lesson and he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.0975)
#   2. ' said' (prob: 0.0381)
#   3. ' then' (prob: 0.0300)
#   4. ' told' (prob: 0.0281)
#   5. ' asked' (prob: 0.0269)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.0997)
#   2. ' said' (prob: 0.0397)
#   3. ' then' (prob: 0.0302)
#   4. ' told' (prob: 0.0286)
#   5. ' asked' (prob: 0.0269)
#
# ---
#   Baseline Generated: The teacher explained the lesson and he was taken aback by the teacher's response.
#
#   Ablated Generated:  The teacher explained the lesson and he was taken aback by the teacher's response.
#
#
#   Generation Changed: False
#   KL Divergence: 0.0004
#
#   Summary for L3H9:
#     Prompts affected: 3/15
#     Average KL Divergence: 0.0009
#
# ----------------------------------------------------------------------
# SUMMARY - Individual Head Ablations (All Heads, All Prompts):
# ----------------------------------------------------------------------
#   L4H0: 5/15 changed (Avg KL: 0.0012)
#   L2H8: 2/15 changed (Avg KL: 0.0006)
#   L3H9: 3/15 changed (Avg KL: 0.0009)
#
# ======================================================================
# --- Part 2: Ablating Top 3 Heads Combined (Core Circuit) ---
# ======================================================================
#
# >>> Testing All 3 Heads Together: [(4, 0), (2, 8), (3, 9)]
#     Testing across 15 prompts...
#
#   --- Prompt 1/15 ---
#
# Prompt: 'The chef prepared the meal and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1207)
#   2. ' said' (prob: 0.0399)
#   3. ' took' (prob: 0.0366)
#   4. ' had' (prob: 0.0348)
#   5. ' asked' (prob: 0.0277)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1188)
#   2. ' said' (prob: 0.0379)
#   3. ' took' (prob: 0.0377)
#   4. ' had' (prob: 0.0357)
#   5. ' asked' (prob: 0.0266)
#
# ---
#   Baseline Generated: The chef prepared the meal and she was so excited to see the results.
#
#
#   Ablated Generated:  The chef prepared the meal and she was so excited to see the chef's face.
#
#   Generation Changed: True
#   KL Divergence: 0.0010
#
#   --- Prompt 2/15 ---
#
# Prompt: 'The company launched the product because it'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1924)
#   2. ' wanted' (prob: 0.0989)
#   3. ' had' (prob: 0.0630)
#   4. ''s' (prob: 0.0527)
#   5. ' is' (prob: 0.0509)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.2004)
#   2. ' wanted' (prob: 0.0958)
#   3. ' had' (prob: 0.0654)
#   4. ''s' (prob: 0.0496)
#   5. ' is' (prob: 0.0494)
#
# ---
#   Baseline Generated: The company launched the product because it was a way to make money on the internet.
#   Ablated Generated:  The company launched the product because it was a way to make money from the sale of
#
#   Generation Changed: True
#   KL Divergence: 0.0012
#
#   --- Prompt 3/15 ---
#
# Prompt: 'The teacher explained the lesson and he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.0975)
#   2. ' said' (prob: 0.0381)
#   3. ' then' (prob: 0.0300)
#   4. ' told' (prob: 0.0281)
#   5. ' asked' (prob: 0.0269)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.0977)
#   2. ' said' (prob: 0.0383)
#   3. ' then' (prob: 0.0302)
#   4. ' asked' (prob: 0.0294)
#   5. ' told' (prob: 0.0292)
#
# ---
#   Baseline Generated: The teacher explained the lesson and he was taken aback by the teacher's response.
#
#   Ablated Generated:  The teacher explained the lesson and he was taken to the hospital.
#
# "I
#
#   Generation Changed: True
#   KL Divergence: 0.0010
#
#   --- Prompt 4/15 ---
#
# Prompt: 'The scientist discovered the cure and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1324)
#   2. ' became' (prob: 0.0302)
#   3. ' took' (prob: 0.0238)
#   4. ' had' (prob: 0.0233)
#   5. ' began' (prob: 0.0230)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1303)
#   2. ' became' (prob: 0.0288)
#   3. ' had' (prob: 0.0250)
#   4. ' took' (prob: 0.0243)
#   5. ' began' (prob: 0.0240)
#
# ---
#   Baseline Generated: The scientist discovered the cure and she was able to cure herself.
#
# The scientist
#   Ablated Generated:  The scientist discovered the cure and she was able to cure herself.
#
# The scientist
#
#   Generation Changed: False
#   KL Divergence: 0.0017
#
#   --- Prompt 5/15 ---
#
# Prompt: 'The artist painted the portrait while he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.6342)
#   2. ' worked' (prob: 0.0320)
#   3. ' and' (prob: 0.0260)
#   4. ' sat' (prob: 0.0179)
#   5. ' had' (prob: 0.0125)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.6339)
#   2. ' worked' (prob: 0.0335)
#   3. ' and' (prob: 0.0257)
#   4. ' sat' (prob: 0.0171)
#   5. ' had' (prob: 0.0116)
#
# ---
#   Baseline Generated: The artist painted the portrait while he was in the hospital.
#
# The artist painted
#   Ablated Generated:  The artist painted the portrait while he was in the hospital.
#
# The artist painted
#
#   Generation Changed: False
#   KL Divergence: 0.0005
#
# ----------------------------------------------------------------------
# SUMMARY - Top 3 Combined Ablation:
# ----------------------------------------------------------------------
# Cases where generation changed: 4/15
# Average KL Divergence: 0.0023
#
# ======================================================================
# --- Part 3: Ablating All 39 Found Heads Combined ---
# ======================================================================
#     Testing across 15 prompts...
#
#   --- Prompt 1/15 ---
#
# Prompt: 'The chef prepared the meal and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1207)
#   2. ' said' (prob: 0.0399)
#   3. ' took' (prob: 0.0366)
#   4. ' had' (prob: 0.0348)
#   5. ' asked' (prob: 0.0277)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1239)
#   2. ' took' (prob: 0.0401)
#   3. ' had' (prob: 0.0389)
#   4. ' said' (prob: 0.0315)
#   5. ' and' (prob: 0.0202)
#
# ---
#   Baseline Generated: The chef prepared the meal and she was so excited to see the results.
#
#
#   Ablated Generated:  The chef prepared the meal and she was so excited to have a meal with her family
#
#   Generation Changed: True
#   KL Divergence: 0.0372
#
#   --- Prompt 2/15 ---
#
# Prompt: 'The company launched the product because it'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1924)
#   2. ' wanted' (prob: 0.0989)
#   3. ' had' (prob: 0.0630)
#   4. ''s' (prob: 0.0527)
#   5. ' is' (prob: 0.0509)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.2165)
#   2. ''s' (prob: 0.0942)
#   3. ' is' (prob: 0.0909)
#   4. ' had' (prob: 0.0552)
#   5. ' wanted' (prob: 0.0433)
#
# ---
#   Baseline Generated: The company launched the product because it was a way to make money on the internet.
#   Ablated Generated:  The company launched the product because it was a way to make money.
#
# "
#
#   Generation Changed: True
#   KL Divergence: 0.1465
#
#   --- Prompt 3/15 ---
#
# Prompt: 'The teacher explained the lesson and he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.0975)
#   2. ' said' (prob: 0.0381)
#   3. ' then' (prob: 0.0300)
#   4. ' told' (prob: 0.0281)
#   5. ' asked' (prob: 0.0269)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.0926)
#   2. ' then' (prob: 0.0393)
#   3. ' said' (prob: 0.0314)
#   4. ' took' (prob: 0.0263)
#   5. ' told' (prob: 0.0251)
#
# ---
#   Baseline Generated: The teacher explained the lesson and he was taken aback by the teacher's response.
#
#   Ablated Generated:  The teacher explained the lesson and he was very impressed.
#
# "I think it
#
#   Generation Changed: True
#   KL Divergence: 0.0315
#
#   --- Prompt 4/15 ---
#
# Prompt: 'The scientist discovered the cure and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1324)
#   2. ' became' (prob: 0.0302)
#   3. ' took' (prob: 0.0238)
#   4. ' had' (prob: 0.0233)
#   5. ' began' (prob: 0.0230)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1577)
#   2. ' had' (prob: 0.0270)
#   3. ' became' (prob: 0.0270)
#   4. ' and' (prob: 0.0251)
#   5. ' is' (prob: 0.0248)
#
# ---
#   Baseline Generated: The scientist discovered the cure and she was able to cure herself.
#
# The scientist
#   Ablated Generated:  The scientist discovered the cure and she was able to get the cure.
#
# "
#
#   Generation Changed: True
#   KL Divergence: 0.0312
#
#   --- Prompt 5/15 ---
#
# Prompt: 'The artist painted the portrait while he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.6342)
#   2. ' worked' (prob: 0.0320)
#   3. ' and' (prob: 0.0260)
#   4. ' sat' (prob: 0.0179)
#   5. ' had' (prob: 0.0125)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.6199)
#   2. ' worked' (prob: 0.0343)
#   3. ' and' (prob: 0.0289)
#   4. ' sat' (prob: 0.0179)
#   5. ' is' (prob: 0.0150)
#
# ---
#   Baseline Generated: The artist painted the portrait while he was in the hospital.
#
# The artist painted
#   Ablated Generated:  The artist painted the portrait while he was in the hospital.
#
# The artist's
#
#   Generation Changed: True
#   KL Divergence: 0.0128
#
# ----------------------------------------------------------------------
# SUMMARY - All Heads Combined Ablation:
# ----------------------------------------------------------------------
# Cases where generation changed: 15/15
# Average KL Divergence: 0.0556
#
# ======================================================================
# FINAL SUMMARY - Circuit Causality Analysis
# ======================================================================
# Circuit: Object->Verb
# Total specialist heads found: 39
# Number of test prompts: 15
#
# Individual heads (top 3):
#   L4H0: 5/15 (33.3%)
#   L2H8: 2/15 (13.3%)
#   L3H9: 3/15 (20.0%)
#
# Top 3 combined: 4/15 (26.7%)
# All heads combined: 15/15 (100.0%)
# ======================================================================

# %%
# Subject->Object 
if __name__ == "__main__" and len(circuits_to_analyze) > 4:
    circuits_to_analyze[4].find_specialists(main_test_cases, threshold=0.1).run_distance_test(distance_test_cases).run_ablation_test(ablation_prompts)
# Out:
# --- DISCOVERY: Found 0 candidates for 'Subject->Object' circuit ---
#
# --- VALIDATION (DISTANCE): No heads to test. Skipping. ---
#
# --- CAUSAL TEST (ABLATION): No heads to test. Skipping. ---

# %%
# Object->Subject 
if __name__ == "__main__" and len(circuits_to_analyze) > 5:
    circuits_to_analyze[5].find_specialists(main_test_cases, threshold=0.1).run_distance_test(distance_test_cases).run_ablation_test(ablation_prompts)
# Out:
# --- DISCOVERY: Found 45 candidates for 'Object->Subject' circuit ---
#   1. L1H6 | Avg Score: 0.4307 | Min Score: 0.1975
#   2. L0H6 | Avg Score: 0.4140 | Min Score: 0.3471
#   3. L6H4 | Avg Score: 0.3822 | Min Score: 0.1746
#   4. L9H5 | Avg Score: 0.3757 | Min Score: 0.0377
#   5. L2H1 | Avg Score: 0.3702 | Min Score: 0.0601
#
# --- VALIDATION (DISTANCE): Testing top 5 specialists for 'Object->Subject' circuit ---
# On sentence: 'The doctor treated the patient'
#   Head     Score
#   L1H6     0.4106
#   L0H6     0.3823
#   L6H4     0.2196
#   L9H5     0.0508
#   L2H1     0.0811
# On sentence: 'The doctor quickly treated the patient'
#   Head     Score
#   L1H6     0.4957
#   L0H6     0.3703
#   L6H4     0.2537
#   L9H5     0.0373
#   L2H1     0.0730
# On sentence: 'The doctor who arrived late treated the patient'
#   Head     Score
#   L1H6     0.6144
#   L0H6     0.3525
#   L6H4     0.1997
#   L9H5     0.0348
#   L2H1     0.0760
#
# --- CAUSAL TEST (ABLATION): Testing specialists for 'Object->Subject' circuit ---
#
# ======================================================================
# --- Part 1: Ablating Top 3 Heads Individually ---
# ======================================================================
#
# >>> Testing Head 1/3: L1H6
#     Testing across 15 prompts...
#
#   --- Prompt 1/15 ---
#
# Prompt: 'The chef prepared the meal and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1207)
#   2. ' said' (prob: 0.0399)
#   3. ' took' (prob: 0.0366)
#   4. ' had' (prob: 0.0348)
#   5. ' asked' (prob: 0.0277)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1191)
#   2. ' said' (prob: 0.0401)
#   3. ' took' (prob: 0.0363)
#   4. ' had' (prob: 0.0346)
#   5. ' asked' (prob: 0.0275)
#
# ---
#   Baseline Generated: The chef prepared the meal and she was so excited to see the results.
#
#
#   Ablated Generated:  The chef prepared the meal and she was so excited to see the results.
#
#
#
#   Generation Changed: False
#   KL Divergence: 0.0005
#
#   --- Prompt 2/15 ---
#
# Prompt: 'The company launched the product because it'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1924)
#   2. ' wanted' (prob: 0.0989)
#   3. ' had' (prob: 0.0630)
#   4. ''s' (prob: 0.0527)
#   5. ' is' (prob: 0.0509)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1893)
#   2. ' wanted' (prob: 0.0984)
#   3. ' had' (prob: 0.0623)
#   4. ''s' (prob: 0.0540)
#   5. ' is' (prob: 0.0530)
#
# ---
#   Baseline Generated: The company launched the product because it was a way to make money on the internet.
#   Ablated Generated:  The company launched the product because it was a way to make money from the sale of
#
#   Generation Changed: True
#   KL Divergence: 0.0004
#
#   --- Prompt 3/15 ---
#
# Prompt: 'The teacher explained the lesson and he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.0975)
#   2. ' said' (prob: 0.0381)
#   3. ' then' (prob: 0.0300)
#   4. ' told' (prob: 0.0281)
#   5. ' asked' (prob: 0.0269)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.0996)
#   2. ' said' (prob: 0.0383)
#   3. ' then' (prob: 0.0295)
#   4. ' told' (prob: 0.0269)
#   5. ' took' (prob: 0.0265)
#
# ---
#   Baseline Generated: The teacher explained the lesson and he was taken aback by the teacher's response.
#
#   Ablated Generated:  The teacher explained the lesson and he was taken aback by the teacher's response.
#
#
#   Generation Changed: False
#   KL Divergence: 0.0003
#
#   Summary for L1H6:
#     Prompts affected: 3/15
#     Average KL Divergence: 0.0004
#
# >>> Testing Head 2/3: L0H6
#     Testing across 15 prompts...
#
#   --- Prompt 1/15 ---
#
# Prompt: 'The chef prepared the meal and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1207)
#   2. ' said' (prob: 0.0399)
#   3. ' took' (prob: 0.0366)
#   4. ' had' (prob: 0.0348)
#   5. ' asked' (prob: 0.0277)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1270)
#   2. ' said' (prob: 0.0403)
#   3. ' took' (prob: 0.0364)
#   4. ' had' (prob: 0.0358)
#   5. ' asked' (prob: 0.0272)
#
# ---
#   Baseline Generated: The chef prepared the meal and she was so excited to see the results.
#
#
#   Ablated Generated:  The chef prepared the meal and she was so excited to see the results.
#
#
#
#   Generation Changed: False
#   KL Divergence: 0.0006
#
#   --- Prompt 2/15 ---
#
# Prompt: 'The company launched the product because it'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1924)
#   2. ' wanted' (prob: 0.0989)
#   3. ' had' (prob: 0.0630)
#   4. ''s' (prob: 0.0527)
#   5. ' is' (prob: 0.0509)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.2072)
#   2. ' wanted' (prob: 0.0811)
#   3. ' had' (prob: 0.0638)
#   4. ''s' (prob: 0.0607)
#   5. ' is' (prob: 0.0574)
#
# ---
#   Baseline Generated: The company launched the product because it was a way to make money on the internet.
#   Ablated Generated:  The company launched the product because it was a way to make money.
#
# "
#
#   Generation Changed: True
#   KL Divergence: 0.0074
#
#   --- Prompt 3/15 ---
#
# Prompt: 'The teacher explained the lesson and he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.0975)
#   2. ' said' (prob: 0.0381)
#   3. ' then' (prob: 0.0300)
#   4. ' told' (prob: 0.0281)
#   5. ' asked' (prob: 0.0269)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1004)
#   2. ' said' (prob: 0.0396)
#   3. ' then' (prob: 0.0309)
#   4. ' told' (prob: 0.0292)
#   5. ' asked' (prob: 0.0260)
#
# ---
#   Baseline Generated: The teacher explained the lesson and he was taken aback by the teacher's response.
#
#   Ablated Generated:  The teacher explained the lesson and he was taken aback by the teacher's response.
#
#
#   Generation Changed: False
#   KL Divergence: 0.0011
#
#   Summary for L0H6:
#     Prompts affected: 5/15
#     Average KL Divergence: 0.0016
#
# >>> Testing Head 3/3: L6H4
#     Testing across 15 prompts...
#
#   --- Prompt 1/15 ---
#
# Prompt: 'The chef prepared the meal and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1207)
#   2. ' said' (prob: 0.0399)
#   3. ' took' (prob: 0.0366)
#   4. ' had' (prob: 0.0348)
#   5. ' asked' (prob: 0.0277)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1183)
#   2. ' said' (prob: 0.0390)
#   3. ' took' (prob: 0.0358)
#   4. ' had' (prob: 0.0345)
#   5. ' asked' (prob: 0.0280)
#
# ---
#   Baseline Generated: The chef prepared the meal and she was so excited to see the results.
#
#
#   Ablated Generated:  The chef prepared the meal and she was so excited to see the results.
#
#
#
#   Generation Changed: False
#   KL Divergence: 0.0005
#
#   --- Prompt 2/15 ---
#
# Prompt: 'The company launched the product because it'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1924)
#   2. ' wanted' (prob: 0.0989)
#   3. ' had' (prob: 0.0630)
#   4. ''s' (prob: 0.0527)
#   5. ' is' (prob: 0.0509)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1907)
#   2. ' wanted' (prob: 0.0979)
#   3. ' had' (prob: 0.0622)
#   4. ' is' (prob: 0.0534)
#   5. ''s' (prob: 0.0516)
#
# ---
#   Baseline Generated: The company launched the product because it was a way to make money on the internet.
#   Ablated Generated:  The company launched the product because it was a way to make money.
#
# "
#
#   Generation Changed: True
#   KL Divergence: 0.0011
#
#   --- Prompt 3/15 ---
#
# Prompt: 'The teacher explained the lesson and he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.0975)
#   2. ' said' (prob: 0.0381)
#   3. ' then' (prob: 0.0300)
#   4. ' told' (prob: 0.0281)
#   5. ' asked' (prob: 0.0269)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.0999)
#   2. ' said' (prob: 0.0355)
#   3. ' then' (prob: 0.0313)
#   4. ' told' (prob: 0.0273)
#   5. ' took' (prob: 0.0269)
#
# ---
#   Baseline Generated: The teacher explained the lesson and he was taken aback by the teacher's response.
#
#   Ablated Generated:  The teacher explained the lesson and he was taken aback by the teacher's response.
#
#
#   Generation Changed: False
#   KL Divergence: 0.0008
#
#   Summary for L6H4:
#     Prompts affected: 4/15
#     Average KL Divergence: 0.0015
#
# ----------------------------------------------------------------------
# SUMMARY - Individual Head Ablations (All Heads, All Prompts):
# ----------------------------------------------------------------------
#   L1H6: 3/15 changed (Avg KL: 0.0004)
#   L0H6: 5/15 changed (Avg KL: 0.0016)
#   L6H4: 4/15 changed (Avg KL: 0.0015)
#
# ======================================================================
# --- Part 2: Ablating Top 3 Heads Combined (Core Circuit) ---
# ======================================================================
#
# >>> Testing All 3 Heads Together: [(1, 6), (0, 6), (6, 4)]
#     Testing across 15 prompts...
#
#   --- Prompt 1/15 ---
#
# Prompt: 'The chef prepared the meal and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1207)
#   2. ' said' (prob: 0.0399)
#   3. ' took' (prob: 0.0366)
#   4. ' had' (prob: 0.0348)
#   5. ' asked' (prob: 0.0277)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1218)
#   2. ' said' (prob: 0.0397)
#   3. ' took' (prob: 0.0355)
#   4. ' had' (prob: 0.0352)
#   5. ' asked' (prob: 0.0274)
#
# ---
#   Baseline Generated: The chef prepared the meal and she was so excited to see the results.
#
#
#   Ablated Generated:  The chef prepared the meal and she was so excited to see the results.
#
#
#
#   Generation Changed: False
#   KL Divergence: 0.0014
#
#   --- Prompt 2/15 ---
#
# Prompt: 'The company launched the product because it'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1924)
#   2. ' wanted' (prob: 0.0989)
#   3. ' had' (prob: 0.0630)
#   4. ''s' (prob: 0.0527)
#   5. ' is' (prob: 0.0509)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.2010)
#   2. ' wanted' (prob: 0.0797)
#   3. ' had' (prob: 0.0625)
#   4. ' is' (prob: 0.0624)
#   5. ''s' (prob: 0.0603)
#
# ---
#   Baseline Generated: The company launched the product because it was a way to make money on the internet.
#   Ablated Generated:  The company launched the product because it was a way to make money.
#
# "
#
#   Generation Changed: True
#   KL Divergence: 0.0119
#
#   --- Prompt 3/15 ---
#
# Prompt: 'The teacher explained the lesson and he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.0975)
#   2. ' said' (prob: 0.0381)
#   3. ' then' (prob: 0.0300)
#   4. ' told' (prob: 0.0281)
#   5. ' asked' (prob: 0.0269)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1044)
#   2. ' said' (prob: 0.0372)
#   3. ' then' (prob: 0.0315)
#   4. ' told' (prob: 0.0274)
#   5. ' took' (prob: 0.0262)
#
# ---
#   Baseline Generated: The teacher explained the lesson and he was taken aback by the teacher's response.
#
#   Ablated Generated:  The teacher explained the lesson and he was taken aback by the teacher's response.
#
#
#   Generation Changed: False
#   KL Divergence: 0.0020
#
#   --- Prompt 4/15 ---
#
# Prompt: 'The scientist discovered the cure and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1324)
#   2. ' became' (prob: 0.0302)
#   3. ' took' (prob: 0.0238)
#   4. ' had' (prob: 0.0233)
#   5. ' began' (prob: 0.0230)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1316)
#   2. ' became' (prob: 0.0295)
#   3. ' took' (prob: 0.0245)
#   4. ' had' (prob: 0.0237)
#   5. ' began' (prob: 0.0225)
#
# ---
#   Baseline Generated: The scientist discovered the cure and she was able to cure herself.
#
# The scientist
#   Ablated Generated:  The scientist discovered the cure and she was able to cure herself.
#
# The scientist
#
#   Generation Changed: False
#   KL Divergence: 0.0009
#
#   --- Prompt 5/15 ---
#
# Prompt: 'The artist painted the portrait while he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.6342)
#   2. ' worked' (prob: 0.0320)
#   3. ' and' (prob: 0.0260)
#   4. ' sat' (prob: 0.0179)
#   5. ' had' (prob: 0.0125)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.6401)
#   2. ' worked' (prob: 0.0329)
#   3. ' and' (prob: 0.0274)
#   4. ' sat' (prob: 0.0172)
#   5. ' had' (prob: 0.0120)
#
# ---
#   Baseline Generated: The artist painted the portrait while he was in the hospital.
#
# The artist painted
#   Ablated Generated:  The artist painted the portrait while he was in the hospital.
#
# The artist painted
#
#   Generation Changed: False
#   KL Divergence: 0.0007
#
# ----------------------------------------------------------------------
# SUMMARY - Top 3 Combined Ablation:
# ----------------------------------------------------------------------
# Cases where generation changed: 4/15
# Average KL Divergence: 0.0034
#
# ======================================================================
# --- Part 3: Ablating All 45 Found Heads Combined ---
# ======================================================================
#     Testing across 15 prompts...
#
#   --- Prompt 1/15 ---
#
# Prompt: 'The chef prepared the meal and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1207)
#   2. ' said' (prob: 0.0399)
#   3. ' took' (prob: 0.0366)
#   4. ' had' (prob: 0.0348)
#   5. ' asked' (prob: 0.0277)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1195)
#   2. ' had' (prob: 0.0351)
#   3. ' said' (prob: 0.0324)
#   4. ' took' (prob: 0.0320)
#   5. ' and' (prob: 0.0219)
#
# ---
#   Baseline Generated: The chef prepared the meal and she was so excited to see the results.
#
#
#   Ablated Generated:  The chef prepared the meal and she was so impressed with the food that she ordered the
#
#   Generation Changed: True
#   KL Divergence: 0.0420
#
#   --- Prompt 2/15 ---
#
# Prompt: 'The company launched the product because it'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1924)
#   2. ' wanted' (prob: 0.0989)
#   3. ' had' (prob: 0.0630)
#   4. ''s' (prob: 0.0527)
#   5. ' is' (prob: 0.0509)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.2513)
#   2. ''s' (prob: 0.0827)
#   3. ' had' (prob: 0.0806)
#   4. ' is' (prob: 0.0789)
#   5. ' could' (prob: 0.0391)
#
# ---
#   Baseline Generated: The company launched the product because it was a way to make money on the internet.
#   Ablated Generated:  The company launched the product because it was the first to offer a "smart" way
#
#   Generation Changed: True
#   KL Divergence: 0.3519
#
#   --- Prompt 3/15 ---
#
# Prompt: 'The teacher explained the lesson and he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.0975)
#   2. ' said' (prob: 0.0381)
#   3. ' then' (prob: 0.0300)
#   4. ' told' (prob: 0.0281)
#   5. ' asked' (prob: 0.0269)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1018)
#   2. ' said' (prob: 0.0240)
#   3. ' went' (prob: 0.0213)
#   4. ' and' (prob: 0.0208)
#   5. ' had' (prob: 0.0198)
#
# ---
#   Baseline Generated: The teacher explained the lesson and he was taken aback by the teacher's response.
#
#   Ablated Generated:  The teacher explained the lesson and he was not surprised.
#
# "I was not
#
#   Generation Changed: True
#   KL Divergence: 0.1421
#
#   --- Prompt 4/15 ---
#
# Prompt: 'The scientist discovered the cure and she'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.1324)
#   2. ' became' (prob: 0.0302)
#   3. ' took' (prob: 0.0238)
#   4. ' had' (prob: 0.0233)
#   5. ' began' (prob: 0.0230)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.1445)
#   2. ' became' (prob: 0.0382)
#   3. ' is' (prob: 0.0236)
#   4. ' gave' (prob: 0.0221)
#   5. ' and' (prob: 0.0211)
#
# ---
#   Baseline Generated: The scientist discovered the cure and she was able to cure herself.
#
# The scientist
#   Ablated Generated:  The scientist discovered the cure and she was able to cure it.
#
# "I
#
#   Generation Changed: True
#   KL Divergence: 0.0583
#
#   --- Prompt 5/15 ---
#
# Prompt: 'The artist painted the portrait while he'
# --------------------------------------------------
# BASELINE Top 5:
#   1. ' was' (prob: 0.6342)
#   2. ' worked' (prob: 0.0320)
#   3. ' and' (prob: 0.0260)
#   4. ' sat' (prob: 0.0179)
#   5. ' had' (prob: 0.0125)
#
# ABLATED Top 5:
#   1. ' was' (prob: 0.4980)
#   2. ' and' (prob: 0.0416)
#   3. ' worked' (prob: 0.0362)
#   4. ' sat' (prob: 0.0260)
#   5. ' waited' (prob: 0.0114)
#
# ---
#   Baseline Generated: The artist painted the portrait while he was in the hospital.
#
# The artist painted
#   Ablated Generated:  The artist painted the portrait while he was in the studio.
#
# The artist was
#
#   Generation Changed: True
#   KL Divergence: 0.0620
#
# ----------------------------------------------------------------------
# SUMMARY - All Heads Combined Ablation:
# ----------------------------------------------------------------------
# Cases where generation changed: 14/15
# Average KL Divergence: 0.1159
#
# ======================================================================
# FINAL SUMMARY - Circuit Causality Analysis
# ======================================================================
# Circuit: Object->Subject
# Total specialist heads found: 45
# Number of test prompts: 15
#
# Individual heads (top 3):
#   L1H6: 3/15 (20.0%)
#   L0H6: 5/15 (33.3%)
#   L6H4: 4/15 (26.7%)
#
# Top 3 combined: 4/15 (26.7%)
# All heads combined: 14/15 (93.3%)
# ======================================================================
